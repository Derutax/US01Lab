# %% [markdown]
# ## Wordbank country indicator analysis
# ### import libraries

# %%
import pandas as pd
import requests

# %% [markdown]
# ### Path to excel file

# %%
path='C:\\Users\\yan_e\\Desktop\\JupyterLab\\Data-sheet-STUDENTS.xlsx'

# %% [markdown]
# ### excelTab get the excel file header is LINE3 of excel (Country, Date, HF Index, Heritage...)

# %%
excelTab = pd.read_excel(path,header=2,index_col=0)

# %%
excelTab['Country (according to CN Gov):']
# Out:
# 1                            Afghanistan
# 2                                Albania
# 3                                Armenia
# 4                             Azerbaijan
# 5                                Bahrain
# 6                             Bangladesh
# 7                                Belarus
# 8                                 Bhutan
# 9                 Bosnia and Herzegovina
# 10                                Brunei
# 11                              Bulgaria
# 12                              Cambodia
# 13                                 China
# 14                               Croatia
# 15                        Czech Republic
# 16                            East Timor
# 17                                 Egypt
# 18                               Estonia
# 19                      France (Not BRI)
# 20                               Georgia
# 21                     Germany (not BRI)
# 22                               Hungary
# 23                                 India
# 24                             Indonesia
# 25                                  Iran
# 26                                  Iraq
# 27                                Israel
# 28                                Jordan
# 29                            Kazakhstan
# 30                                Kuwait
#                      ...
# 39                               Moldova
# 40                              Mongolia
# 41                            Montenegro
# 42                               Myanmar
# 43                                 Nepal
# 44                                  Oman
# 45                              Pakistan
# 46                           Philippines
# 47                                Poland
# 48                                 Qatar
# 49                               Romania
# 50                                Russia
# 51                          Saudi Arabia
# 52                                Serbia
# 53                             Singapore
# 54                              Slovakia
# 55                              Slovenia
# 56                             Sri Lanka
# 57                                 Syria
# 58                            Tajikistan
# 59                             Thailiand
# 60              The United Arab Emirates
# 61                                Turkey
# 62                          Turkmenistan
# 63              United Kingdom (Not BRI)
# 64    United States of America (Not BRI)
# 65                               Ukraine
# 66                            Uzbekistan
# 67                               Vietnam
# 68                                 Yemen
# Name: Country (according to CN Gov):, Length: 68, dtype: object

# %% [markdown]
# ## Getting isocode3 + exceptions (India, Thialand, UAE, paranthesis city)

# %%
restCountryURL = 'https://restcountries.eu/rest/v2/name/'
reqAnswer = ''
isoCodes = {}

# %%
for index , name in excelTab['Country (according to CN Gov):'].items():
    if name in isoCodes:
        continue
    reducedName= name.split('(')[0]
    reducedName=reducedName.strip()
    if reducedName == 'Thailiand':
        reducedName = 'thailand'
    if reducedName == 'The United Arab Emirates':
        reducedName = 'United Arab Emirates'
    ##if name[-1:]==' ':
    ##    name = name[:-1]
    req = requests.get(restCountryURL+reducedName)
    if req.status_code ==200:
        reqAnswer = req.json()
        countryCode = reqAnswer[0]['alpha3Code']
        if countryCode =='IOT':
            countryCode = reqAnswer[1]['alpha3Code']
        isoCodes[name] = countryCode
    else:
        print('[ERROR]', req.status_code, req.text , name)

# %%
isoCodes
# Out:
# {'Afghanistan': 'AFG',
#  'Albania': 'ALB',
#  'Armenia': 'ARM',
#  'Azerbaijan': 'AZE',
#  'Bahrain': 'BHR',
#  'Bangladesh': 'BGD',
#  'Belarus': 'BLR',
#  'Bhutan': 'BTN',
#  'Bosnia and Herzegovina': 'BIH',
#  'Brunei': 'BRN',
#  'Bulgaria': 'BGR',
#  'Cambodia': 'KHM',
#  'China': 'CHN',
#  'Croatia': 'HRV',
#  'Czech Republic': 'CZE',
#  'East Timor': 'TLS',
#  'Egypt': 'EGY',
#  'Estonia': 'EST',
#  'France (Not BRI)': 'FRA',
#  'Georgia': 'GEO',
#  'Germany (not BRI)': 'DEU',
#  'Hungary': 'HUN',
#  'India': 'IND',
#  'Indonesia': 'IDN',
#  'Iran': 'IRN',
#  'Iraq': 'IRQ',
#  'Israel': 'ISR',
#  'Jordan': 'JOR',
#  'Kazakhstan': 'KAZ',
#  'Kuwait': 'KWT',
#  'Kyrgyzstan': 'KGZ',
#  'Laos': 'LAO',
#  'Latvia': 'LVA',
#  'Lebanon': 'LBN',
#  'Lithuania': 'LTU',
#  'Macedonia': 'MKD',
#  'Malaysia': 'MYS',
#  'Maldives': 'MDV',
#  'Moldova': 'MDA',
#  'Mongolia': 'MNG',
#  'Montenegro': 'MNE',
#  'Myanmar': 'MMR',
#  'Nepal': 'NPL',
#  'Oman': 'OMN',
#  'Pakistan': 'PAK',
#  'Philippines': 'PHL',
#  'Poland': 'POL',
#  'Qatar': 'QAT',
#  'Romania': 'ROU',
#  'Russia': 'RUS',
#  'Saudi Arabia': 'SAU',
#  'Serbia': 'SRB',
#  'Singapore': 'SGP',
#  'Slovakia': 'SVK',
#  'Slovenia': 'SVN',
#  'Sri Lanka': 'LKA',
#  'Syria': 'SYR',
#  'Tajikistan': 'TJK',
#  'Thailiand': 'THA',
#  'The United Arab Emirates': 'ARE',
#  'Turkey': 'TUR',
#  'Turkmenistan': 'TKM',
#  'United Kingdom (Not BRI)': 'GBR',
#  'United States of America (Not BRI)': 'USA',
#  'Ukraine': 'UKR',
#  'Uzbekistan': 'UZB',
#  'Vietnam': 'VNM',
#  'Yemen': 'YEM'}

# %%
excelTab['isocode'] = excelTab['Country (according to CN Gov):'].apply(lambda x: isoCodes[x])

# %%
excelTab[['isocode','Country (according to CN Gov):']]
# Out:
#    isocode      Country (according to CN Gov):
# 1      AFG                         Afghanistan
# 2      ALB                             Albania
# 3      ARM                             Armenia
# 4      AZE                          Azerbaijan
# 5      BHR                             Bahrain
# 6      BGD                          Bangladesh
# 7      BLR                             Belarus
# 8      BTN                              Bhutan
# 9      BIH              Bosnia and Herzegovina
# 10     BRN                              Brunei
# 11     BGR                            Bulgaria
# 12     KHM                            Cambodia
# 13     CHN                               China
# 14     HRV                             Croatia
# 15     CZE                      Czech Republic
# 16     TLS                          East Timor
# 17     EGY                               Egypt
# 18     EST                             Estonia
# 19     FRA                    France (Not BRI)
# 20     GEO                             Georgia
# 21     DEU                   Germany (not BRI)
# 22     HUN                             Hungary
# 23     IND                               India
# 24     IDN                           Indonesia
# 25     IRN                                Iran
# 26     IRQ                                Iraq
# 27     ISR                              Israel
# 28     JOR                              Jordan
# 29     KAZ                          Kazakhstan
# 30     KWT                              Kuwait
# ..     ...                                 ...
# 39     MDA                             Moldova
# 40     MNG                            Mongolia
# 41     MNE                          Montenegro
# 42     MMR                             Myanmar
# 43     NPL                               Nepal
# 44     OMN                                Oman
# 45     PAK                            Pakistan
# 46     PHL                         Philippines
# 47     POL                              Poland
# 48     QAT                               Qatar
# 49     ROU                             Romania
# 50     RUS                              Russia
# 51     SAU                        Saudi Arabia
# 52     SRB                              Serbia
# 53     SGP                           Singapore
# 54     SVK                            Slovakia
# 55     SVN                            Slovenia
# 56     LKA                           Sri Lanka
# 57     SYR                               Syria
# 58     TJK                          Tajikistan
# 59     THA                           Thailiand
# 60     ARE            The United Arab Emirates
# 61     TUR                              Turkey
# 62     TKM                        Turkmenistan
# 63     GBR            United Kingdom (Not BRI)
# 64     USA  United States of America (Not BRI)
# 65     UKR                             Ukraine
# 66     UZB                          Uzbekistan
# 67     VNM                             Vietnam
# 68     YEM                               Yemen
#
# [68 rows x 2 columns]

# %% [markdown]
# ## Getting all world bank records

# %%
isoDone={}
cntryDone={}
indicators = ['FB.AST.NPER.ZS','GC.TAX.IMPT.ZS','IS.RRS.GOOD.MT.K6','NE.CON.PRVT.PP.CD','GB.XPD.RSDV.GD.ZS','SP.POP.SCIE.RD.P6','BX.KLT.DINV.WD.GD.ZS','SH.XPD.CHEX.PP.CD','GB.XPD.RSDV.GD.ZS','IP.TMK.RSCT','IP.PAT.RESD']

# %%
indicators
# Out:
# ['FB.AST.NPER.ZS',
#  'GC.TAX.IMPT.ZS',
#  'IS.RRS.GOOD.MT.K6',
#  'NE.CON.PRVT.PP.CD',
#  'GB.XPD.RSDV.GD.ZS',
#  'SP.POP.SCIE.RD.P6',
#  'BX.KLT.DINV.WD.GD.ZS',
#  'SH.XPD.CHEX.PP.CD',
#  'GB.XPD.RSDV.GD.ZS',
#  'IP.TMK.RSCT',
#  'IP.PAT.RESD']

# %%
isoCodes
# Out:
# {'Afghanistan': 'AFG',
#  'Albania': 'ALB',
#  'Armenia': 'ARM',
#  'Azerbaijan': 'AZE',
#  'Bahrain': 'BHR',
#  'Bangladesh': 'BGD',
#  'Belarus': 'BLR',
#  'Bhutan': 'BTN',
#  'Bosnia and Herzegovina': 'BIH',
#  'Brunei': 'BRN',
#  'Bulgaria': 'BGR',
#  'Cambodia': 'KHM',
#  'China': 'CHN',
#  'Croatia': 'HRV',
#  'Czech Republic': 'CZE',
#  'East Timor': 'TLS',
#  'Egypt': 'EGY',
#  'Estonia': 'EST',
#  'France (Not BRI)': 'FRA',
#  'Georgia': 'GEO',
#  'Germany (not BRI)': 'DEU',
#  'Hungary': 'HUN',
#  'India': 'IND',
#  'Indonesia': 'IDN',
#  'Iran': 'IRN',
#  'Iraq': 'IRQ',
#  'Israel': 'ISR',
#  'Jordan': 'JOR',
#  'Kazakhstan': 'KAZ',
#  'Kuwait': 'KWT',
#  'Kyrgyzstan': 'KGZ',
#  'Laos': 'LAO',
#  'Latvia': 'LVA',
#  'Lebanon': 'LBN',
#  'Lithuania': 'LTU',
#  'Macedonia': 'MKD',
#  'Malaysia': 'MYS',
#  'Maldives': 'MDV',
#  'Moldova': 'MDA',
#  'Mongolia': 'MNG',
#  'Montenegro': 'MNE',
#  'Myanmar': 'MMR',
#  'Nepal': 'NPL',
#  'Oman': 'OMN',
#  'Pakistan': 'PAK',
#  'Philippines': 'PHL',
#  'Poland': 'POL',
#  'Qatar': 'QAT',
#  'Romania': 'ROU',
#  'Russia': 'RUS',
#  'Saudi Arabia': 'SAU',
#  'Serbia': 'SRB',
#  'Singapore': 'SGP',
#  'Slovakia': 'SVK',
#  'Slovenia': 'SVN',
#  'Sri Lanka': 'LKA',
#  'Syria': 'SYR',
#  'Tajikistan': 'TJK',
#  'Thailiand': 'THA',
#  'The United Arab Emirates': 'ARE',
#  'Turkey': 'TUR',
#  'Turkmenistan': 'TKM',
#  'United Kingdom (Not BRI)': 'GBR',
#  'United States of America (Not BRI)': 'USA',
#  'Ukraine': 'UKR',
#  'Uzbekistan': 'UZB',
#  'Vietnam': 'VNM',
#  'Yemen': 'YEM'}

# %%
for index , name in excelTab['isocode'].items():
    if name in cntryDone:
        continue
    for indic in indicators:
        req = requests.get('http://api.worldbank.org/v2/country/'+excelTab['isocode'][index]+'/indicator/'+indic+'?format=json')
        reqAnswer = req.json()
        done = 0
        indexJ = 0
        while not done:
            if indexJ<len(reqAnswer[1]):
                if reqAnswer[1][indexJ]['value']!=None:
                    done = 1
                    isoDone[name]= reqAnswer[1][indexJ]['value']
                elif indexJ==10:
                    isoDone[name]=0
                    done = 1
            else:
                isoDone[name]=0
                done = 1
            indexJ=indexJ+1
        if (indic == 'FB.AST.NPER.ZS'):
            excelURL = 'WB IMF Non-performing loans to total gross loans ratio (%)'
        elif (indic == 'GC.TAX.IMPT.ZS' ):
            excelURL = 'IMF WB \nCustoms and other import duties (% of tax revenue) 2016'
        elif(indic == 'IS.RRS.GOOD.MT.K6'):
            excelURL = 'UIC Rail freight (mn ton x km travelled)'
            excelTab =  excelTab.assign(excelTab[excelURL][index] = isoDone[name])
            excelURL = 'ICAO air freight (mn ton x km travelled)'
        elif (indic =='NE.CON.PRVT.PP.CD'):
            excelURL = 'WB Household final consumption expenditure, PPP bn USD'
        elif (indic == 'GB.XPD.RSDV.GD.ZS'):
            excelURL = 'WB UNESCO R&D Expenditure % of GDP'
        elif (indic =='SP.POP.SCIE.RD.P6'):
            excelURL = 'WB UNESCO Researchers p. mn inhabitants'
        elif (indic =='BX.KLT.DINV.WD.GD.ZS'):
            excelURL = 'IFDI Net Inflows (% of GDP)'
        elif (indic == 'SH.XPD.CHEX.PP.CD'):
            excelURL = 'WHO Current Health Expenditure p.c., PPP USD'
        elif (indic == 'GB.XPD.RSDV.GD.ZS'):
            excelURL = 'WB Research Expenditure % of GDP'
        elif (indic == 'IP.TMK.RSCT'):
            excelURL = 'WIPO Trademark applications'
        elif (indic == 'IP.PAT.RESD'):
            excelURL = 'WIPO Patent Applications'  
        excelTab =  excelTab.assign(excelTab[excelURL][index] = isoDone[name])
        print(name+ ', got '+ indic+' in '+ excelURL)
    cntryDone[name]=1
    isoDone={}
    if excelTab['isocode'][index]=='ALB':
        break
# Out:
#   File "<ipython-input-114-b332acb4bbd0>", line 27
#     excelTab =  excelTab.assign(excelTab[excelURL][index] = isoDone[name])
#                                ^
# SyntaxError: keyword can't be an expression

# %%
excelTab['isocode'][2]
# Out:
# 'ALB'

# %%
excelTab['WIPO Trademark applications'][12]
# Out:
# 1.182

# %%
print(isoDone['AFG'])
# Out:
# 12.2018301907814

# %%
for indic in indicators:
    print (indic)
    for index , name in excelTab['isocode'].items():
        if name in isoDone:
            continue
        req = requests.get('http://api.worldbank.org/v2/country/'+excelTab['isocode'][index]+'/indicator/'+indic+'?format=json')
        req.status_code
        reqAnswer = req.json()
        indexJ=1
        done= 0
        while not done : 
            if reqAnswer[1][indexJ]['value']!=None:
                done=1
                print(name)
                print(indexJ)
                isoDone[name] = reqAnswer[1][indexJ]['value']
            if indexJ==10:    
                isoDone[name] =0
                break
            indexJ=indexJ+1
    ##break
        ##print(req.json())
        ##req.json()
   ## excelTab['WBIMF'] = excelTab['isocode'].apply(lambda x: isoDone[x])
##Tried version
# Out:
# FB.AST.NPER.ZS
# AFG
# 0
# 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-011dcad93e80> in <module>
#      16                 print(jindex)
#      17                 print(indexJ)
# ---> 18                 isoDone[name][jindex] = reqAnswer[1][indexJ]['value']
#      19             if indexJ==10:
#      20                 isoDone[name][jindex] =0
#
# KeyError: 'AFG'

# %% [markdown]
# #TODO do all worldbank stuff API

# %%
isoDone[0,0]= 'AFG'

# %%
excelTab['WB IMF Non-performing loans to total gross loans ratio (%)'] = excelTab['isocode'].apply(lambda x: isoDone[x])

# %%
excelTab[['isocode','Country (according to CN Gov):','WBIMF']]

# %%
indicators

# %%
for index , name in excelTab['isocode'].items():
    if name in isoDone:
        continue
    req = requests.get('http://api.worldbank.org/v2/country/'+excelTab['isocode'][index]+'/indicator/FB.AST.NPER.ZS?format=json')
    req.status_code
    reqAnswer = req.json()
    indexJ=1
    done= 0
    while not done : 
        if reqAnswer[1][indexJ]['value']!=None:
            done=1
            isoDone[name] = reqAnswer[1][indexJ]['value']
        if indexJ==10:    
            isoDone[name] =0
            break
        indexJ=indexJ+1
    ##break
    ##print(req.json())
    ##req.json()
    ##old version

# %%
excelTab
# Out:
#         Country (according to CN Gov): Date of research inquiry  \
# 1                          Afghanistan                      NaT
# 2                              Albania                      NaT
# 3                              Armenia                      NaT
# 4                           Azerbaijan                      NaT
# 5                              Bahrain                      NaT
# 6                           Bangladesh                      NaT
# 7                              Belarus                      NaT
# 8                               Bhutan                      NaT
# 9               Bosnia and Herzegovina                      NaT
# 10                              Brunei                      NaT
# 11                            Bulgaria                      NaT
# 12                            Cambodia               2018-08-16
# 13                               China                      NaT
# 14                             Croatia                      NaT
# 15                      Czech Republic                      NaT
# 16                          East Timor                      NaT
# 17                               Egypt                      NaT
# 18                             Estonia                      NaT
# 19                    France (Not BRI)                      NaT
# 20                             Georgia                      NaT
# 21                   Germany (not BRI)                      NaT
# 22                             Hungary                      NaT
# 23                               India                      NaT
# 24                           Indonesia                      NaT
# 25                                Iran                      NaT
# 26                                Iraq                      NaT
# 27                              Israel                      NaT
# 28                              Jordan                      NaT
# 29                          Kazakhstan                      NaT
# 30                              Kuwait                      NaT
# ..                                 ...                      ...
# 39                             Moldova                      NaT
# 40                            Mongolia                      NaT
# 41                          Montenegro                      NaT
# 42                             Myanmar                      NaT
# 43                               Nepal                      NaT
# 44                                Oman                      NaT
# 45                            Pakistan                      NaT
# 46                         Philippines                      NaT
# 47                              Poland                      NaT
# 48                               Qatar                      NaT
# 49                             Romania                      NaT
# 50                              Russia                      NaT
# 51                        Saudi Arabia                      NaT
# 52                              Serbia                      NaT
# 53                           Singapore                      NaT
# 54                            Slovakia                      NaT
# 55                            Slovenia                      NaT
# 56                           Sri Lanka                      NaT
# 57                               Syria                      NaT
# 58                          Tajikistan                      NaT
# 59                           Thailiand                      NaT
# 60            The United Arab Emirates                      NaT
# 61                              Turkey                      NaT
# 62                        Turkmenistan                      NaT
# 63            United Kingdom (Not BRI)                      NaT
# 64  United States of America (Not BRI)                      NaT
# 65                             Ukraine                      NaT
# 66                          Uzbekistan                      NaT
# 67                             Vietnam                      NaT
# 68                               Yemen                      NaT
#
#     HF Index of Economic Freedom (Scale: 1-100)  \
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                         58.7
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                         37.0
# 20                                          NaN
# 21                                         34.0
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                          NaN
# ..                                          ...
# 39                                          NaN
# 40                                          NaN
# 41                                          NaN
# 42                                          NaN
# 43                                          NaN
# 44                                          NaN
# 45                                          NaN
# 46                                          NaN
# 47                                          NaN
# 48                                          NaN
# 49                                          NaN
# 50                                          NaN
# 51                                          NaN
# 52                                          NaN
# 53                                          NaN
# 54                                          NaN
# 55                                          NaN
# 56                                          NaN
# 57                                          NaN
# 58                                          NaN
# 59                                         62.0
# 60                                          NaN
# 61                                          NaN
# 62                                          NaN
# 63                                         55.0
# 64                                          NaN
# 65                                          NaN
# 66                                          NaN
# 67                                          NaN
# 68                                          NaN
#
#     Heritage Foundation Index of Economic Freedom (Global Ranking)  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                              101.0
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# ..                                                ...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
#
#     Bertelsmann Transformation index (BTI)  \
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     4.0
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# 30                                     NaN
# ..                                     ...
# 39                                     NaN
# 40                                     NaN
# 41                                     NaN
# 42                                     NaN
# 43                                     NaN
# 44                                     NaN
# 45                                     NaN
# 46                                     NaN
# 47                                     NaN
# 48                                     NaN
# 49                                     NaN
# 50                                     NaN
# 51                                     NaN
# 52                                     NaN
# 53                                     NaN
# 54                                     NaN
# 55                                     NaN
# 56                                     NaN
# 57                                     NaN
# 58                                     NaN
# 59                                     NaN
# 60                                     NaN
# 61                                     NaN
# 62                                     NaN
# 63                                     NaN
# 64                                     NaN
# 65                                     NaN
# 66                                     NaN
# 67                                     NaN
# 68                                     NaN
#
#     Bertelsmann Transformation index (BTI) - Ranking  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                             103.0
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# ..                                               ...
# 39                                               NaN
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
# 48                                               NaN
# 49                                               NaN
# 50                                               NaN
# 51                                               NaN
# 52                                               NaN
# 53                                               NaN
# 54                                               NaN
# 55                                               NaN
# 56                                               NaN
# 57                                               NaN
# 58                                               NaN
# 59                                               NaN
# 60                                               NaN
# 61                                               NaN
# 62                                               NaN
# 63                                               NaN
# 64                                               NaN
# 65                                               NaN
# 66                                               NaN
# 67                                               NaN
# 68                                               NaN
#
#     IMF WB\nCustoms and other import duties (% of tax revenue) 2016  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                             15.785
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# ..                                                ...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
#
#     WB IMF Non-performing loans to total gross loans ratio (%)  \
# 1                                            12.20183
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                            0.02072
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# ..                                                ...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
#
#    Moody's Socvereign Ratings List S&P Sovereign Ratings List  ...        A  \
# 1                              NaN                        NaN  ...  144  46
# 2                              NaN                        NaN  ...  144  46
# 3                              NaN                        NaN  ...  144  46
# 4                              NaN                        NaN  ...  144  46
# 5                              NaN                        NaN  ...  144  46
# 6                              NaN                        NaN  ...  144  46
# 7                              NaN                        NaN  ...  144  46
# 8                              NaN                        NaN  ...  144  46
# 9                              NaN                        NaN  ...  144  46
# 10                             NaN                        NaN  ...  144  46
# 11                             NaN                        NaN  ...  144  46
# 12                              B2                         B+  ...  144  46
# 13                             NaN                        NaN  ...  144  46
# 14                             NaN                        NaN  ...  144  46
# 15                             NaN                        NaN  ...  144  46
# 16                             NaN                        NaN  ...  144  46
# 17                             NaN                        NaN  ...  144  46
# 18                             NaN                        NaN  ...  144  46
# 19                             NaN                        NaN  ...  144  46
# 20                             NaN                        NaN  ...  144  46
# 21                             NaN                        NaN  ...  144  46
# 22                             NaN                        NaN  ...  144  46
# 23                             NaN                        NaN  ...  144  46
# 24                             NaN                        NaN  ...  144  46
# 25                             NaN                        NaN  ...  144  46
# 26                             NaN                        NaN  ...  144  46
# 27                             NaN                        NaN  ...  144  46
# 28                             NaN                        NaN  ...  144  46
# 29                             NaN                        NaN  ...  144  46
# 30                             NaN                        NaN  ...  144  46
# ..                             ...                        ...  ...  ...  ..
# 39                             NaN                        NaN  ...  144  46
# 40                             NaN                        NaN  ...  144  46
# 41                             NaN                        NaN  ...  144  46
# 42                             NaN                        NaN  ...  144  46
# 43                             NaN                        NaN  ...  144  46
# 44                             NaN                        NaN  ...  144  46
# 45                             NaN                        NaN  ...  144  46
# 46                             NaN                        NaN  ...  144  46
# 47                             NaN                        NaN  ...  144  46
# 48                             NaN                        NaN  ...  144  46
# 49                             NaN                        NaN  ...  144  46
# 50                             NaN                        NaN  ...  144  46
# 51                             NaN                        NaN  ...  144  46
# 52                             NaN                        NaN  ...  144  46
# 53                             NaN                        NaN  ...  144  46
# 54                             NaN                        NaN  ...  144  46
# 55                             NaN                        NaN  ...  144  46
# 56                             NaN                        NaN  ...  144  46
# 57                             NaN                        NaN  ...  144  46
# 58                             NaN                        NaN  ...  144  46
# 59                             NaN                        NaN  ...  144  46
# 60                             NaN                        NaN  ...  144  46
# 61                             NaN                        NaN  ...  144  46
# 62                             NaN                        NaN  ...  144  46
# 63                             NaN                        NaN  ...  144  46
# 64                             NaN                        NaN  ...  144  46
# 65                             NaN                        NaN  ...  144  46
# 66                             NaN                        NaN  ...  144  46
# 67                             NaN                        NaN  ...  144  46
# 68                             NaN                        NaN  ...  144  46
#
#            D    O   P       U         W     R             o        N
# 1   8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 2   8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 3   8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 4   8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 5   8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 6   8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 7   8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 8   8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 9   8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 10  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 11  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 12  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 13  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 14  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 15  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 16  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 17  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 18  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 19  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 20  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 21  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 22  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 23  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 24  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 25  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 26  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 27  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 28  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 29  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 30  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# ..       ...  ...  ..     ...       ...   ...           ...      ...
# 39  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 40  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 41  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 42  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 43  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 44  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 45  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 46  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 47  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 48  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 49  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 50  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 51  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 52  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 53  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 54  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 55  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 56  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 57  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 58  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 59  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 60  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 61  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 62  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 63  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 64  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 65  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 66  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 67  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
# 68  8.015508  107  14  0.2277  7.571847  4633  1.018162e+11  0.18521
#
# [68 rows x 60 columns]
