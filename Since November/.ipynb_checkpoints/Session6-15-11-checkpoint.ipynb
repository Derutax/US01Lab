# %%
import pandas as pd

# %%
import geopandas

# %%
from osgeo import osr, ogr

# %%
path='C:\\Users\\yan_e\\Desktop\\JupyterLab\\Since November\\UTSEUS-MOBIKE-shanghai_full.csv'

# %%
df =pd.read_csv('UTSEUS-MOBIKE-shanghai_full.csv',index_col='orderid')
# Out:
# D:\Travail\application\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df.head()
# Out:
#          bikeid  userid        start_time  start_location_x  start_location_y  \
# orderid
# 1        324731    7541  2016-08-28 00:00           121.490            31.280
# 6        288841    4427  2016-08-28 00:00           121.462            31.313
# 8        315873    6474  2016-08-28 00:00           121.416            31.154
# 10        93155   12616  2016-08-28 00:00           121.436            31.320
# 11       352484   11596  2016-08-28 00:00           121.459            31.325
#
#                  end_time  end_location_x  end_location_y  \
# orderid
# 1        2016-08-28 00:08         121.486          31.273
# 6        2016-08-28 00:17         121.455          31.315
# 8        2016-08-28 00:14         121.419          31.156
# 10       2016-08-28 00:12         121.444          31.310
# 11       2016-08-28 00:08         121.460          31.315
#
#                                                      track
# orderid
# ...

# %%
# %matplotlib inline
df.plot.scatter(x='start_location_x',y='start_location_y');

# %%
df= df[(df['start_location_x']>121.10157)&(df['start_location_x']<121.804611)&(df['start_location_y']>30.975)&(df['start_location_y']<31.514955)]

# %%
df.plot.scatter(x='start_location_x',y='start_location_y',s=0.01,c="#FF00FF50",figsize=(20,15));

# %%
df['start'] = pd.to_datetime(df['start_time'])

# %%
df['end'] = pd.to_datetime(df['end_time'])

# %%
df['timespent']= df['end']-df['start']

# %%
import os
os.environ['GDAL_DATA'] = 'D:\\Travail\\application\\Anaconda3\\pkgs\\libgdal-2.3.3-h10f50ba_0\\Library\\share\\gdal'

from osgeo import osr, ogr
old_crs = osr.SpatialReference()
old_crs.ImportFromEPSG(4326)
new_crs = osr.SpatialReference()
new_crs.ImportFromEPSG(4479)
transform = osr.CoordinateTransformation(old_crs,new_crs)
def getNewLongitude( xy ):
    point = ogr.Geometry(ogr.wkbPoint)
    point.AddPoint(xy[0],xy[1])
    point.Transform(transform)
    return point.GetX()
def getNewLatitude (xy):
    point = ogr.Geometry(ogr.wkbPoint)
    point.AddPoint(xy[0],xy[1])
    point.Transform(transform)
    return point.GetY()
df['longitude'] = df[['start_location_x','start_location_y']].apply(getNewLongitude,axis=1)

df['latitude'] = df[['start_location_x','start_location_y']].apply(getNewLatitude,axis=1)
df = df.drop(columns=['start_location_x', 'start_location_y'],axis=1)
df.head()
# Out:
#          bikeid  userid        start_time          end_time  end_location_x  \
# orderid
# 1        324731    7541  2016-08-28 00:00  2016-08-28 00:08         121.486
# 6        288841    4427  2016-08-28 00:00  2016-08-28 00:17         121.455
# 8        315873    6474  2016-08-28 00:00  2016-08-28 00:14         121.419
# 10        93155   12616  2016-08-28 00:00  2016-08-28 00:12         121.444
# 11       352484   11596  2016-08-28 00:00  2016-08-28 00:08         121.460
#
#          end_location_y                                              track  \
# orderid
# 1                31.273  121.485,31.275#121.485,31.276#121.486,31.273#1...
# 6                31.315  121.455,31.313#121.455,31.314#121.455,31.315#1...
# 8                31.156  121.416,31.154#121.416,31.155#121.417,31.155#1...
# 10               31.310  121.436,31.318#121.436,31.319#121.436,31.320#1...
# 11               31.315  121.459,31.315#121.459,31.316#121.459,31.317#1...
#
# ...

# %%
import pyproj

mercator = pyproj.Proj(init="EPSG:4326",preserve_units=False)
chinaGDS = pyproj.Proj(init="EPSG:4479",preserve_units=False)
pyproj.transform(mercator,china,121,38,radians=False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-cdf8f57300bb> in <module>
#       1 import pyproj
#       2
# ----> 3 mercator = pyproj.Proj(init="EPSG:4326",preserve_units=False)
#       4 chinaGDS = pyproj.Proj(init="EPSG:4479",preserve_units=False)
#       5 pyproj.transform(mercator,china,121,38,radians=False)
#
# D:\Travail\application\Anaconda3\lib\site-packages\pyproj\__init__.py in __new__(self, projparams, preserve_units, **kwargs)
#     360         # on case-insensitive filesystems).
#     361         projstring = projstring.replace('EPSG','epsg')
# --> 362         return _proj.Proj.__new__(self, projstring)
#     363
#     364     def __call__(self, *args, **kw):
#
# _proj.pyx in _proj.Proj.__cinit__()
#
# RuntimeError: b'no arguments in initialization list'

# %%
from pyproj import Transformer
transformer = Transformer.from_crs("EPSG:4326", "EPSG:4479", always_xy=True)
transformer.transform(121,38)

# %%
from pyproj import Transformer

# %%
test = pd.Timestamp(df.end_time[1]) -pd.Timestamp(df.start_time[1])
test
